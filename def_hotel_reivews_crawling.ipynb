# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       4 browser = Chrome()
#       5 browser.get(url)
# ----> 6 more_links = browser.find_elements_by_css_selector('.taLnk.ulBlueLinks')
#       7 more_links[0].click()
#       8 reviews = browser.find_elements_by_css_selector('.partial_entry')
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_by_css_selector'

# %%
# !pip install selenium

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user\Documents\Python Scripts

# %%
from selenium.webdriver import Chrome
import os

# %% [markdown]
# # 취합 코드

# %%
url = 'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-Lotte_City_Hotel_Daejeon-Daejeon.html'
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import time
browser = Chrome()
browser.get(url)
n=0
review_list=[]
flag = True
while flag:
    # 리뷰 태그를  검색
    class_reviews = browser.find_elements(By.CSS_SELECTOR,'.QewHA.H4._a > span')
    # 검색된 리뷰 태그에서 데이터 추출
    for span_review in class_reviews:
        review_text = span_review.text
        review_list.append(review_text)
        
    # 다음 페이지로 넘어가는 버튼 태그 검색
    link = "#component_15 > div > div:nth-child(3) > div.MD > div > a"
    next_page = browser.find_elements(By.CSS_SELECTOR,link)
    

    # 더이상 다음 페이지가 없으면 
    if link == False:
        falg = False
    else:

        next_page[0].click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[109], line 18
#      16 # 검색된 리뷰 태그에서 데이터 추출
#      17 for span_review in class_reviews:
# ---> 18     review_text = span_review.text
#      19     review_list.append(review_text)
#      20 # 더이상 다음 페이지가 없으면
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# ...

# %% [markdown]
# ## 리뷰 가져오기

# %%
url = 'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-Lotte_City_Hotel_Daejeon-Daejeon.html'
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import time
browser = Chrome()
browser.get(url)
re_list = []
class_reviews = browser.find_elements(By.CSS_SELECTOR,'.QewHA.H4._a > span')
for span_review in class_reviews:
    re_list.append(span_review.text)

# %%
re_list
# Out:
# ['헐리우드 부터 다양한 룸타입과 계절별 PKG등 여러 프로모션이 있는것 좋지만 최근 구로에 숙박한후 대전 을 기록한다 헐리우드 킹인데 더블을 두개 붙여놓았었던 적도 있고, 가급적 조용함을 원했는데 층별실외기가 있는방으로 배치받아 교체를 했던적도 있고 구로, 김포, 대전, 마포 등 여러 롯데시티중에서 주차장 이용은 나름 부족한 부분이 없으나 배려가 너무 부족한것 같다 4월 5월 이용시 한번의 조식 이용도 예전에 비해 퀄리티가 많이 떨어졌다 작년 코로나땐 엄청 세심했는데 지금은 너무 아쉬운곳',
#  '뷰가 특별한건없고 그냥 편하게 자기 좋은곳!! 이건 체크아웃 하고나서 알게된 사실인데 미리 가습기 얘기하면 무료대여(?) 할수있다!! 친구가 자는데 건조하다해서 검색해보니 그런서비스도🤭',
#  '갑천과 유등천의 흐름을 한눈에 볼수 있는 대전에선 최고의 리버뷰를 자랑합니다. 침실과 다용도실이 나눠져있어서 공간 분리도 훌륭하고, 역시나 청소상태 침구류 상태 최상입니다 잘쉬었다가 갑니다!',
#  '시설이 깔끔하고 조용합니다. 근처에 식당과 술집이 많지는 않습니다. 편의점은 옆건물에 있습니다. 대전 시내 중심가까지 택시를 이용했습니다.',
#  '고향에 갈때마다 언제나 투숙하는 곳입니다. 신축 호텔이라 그런지 깔끔한 인상을 주는 곳입니다. 객실 컨디션도 만족합니다. 갑천을 바라보는 뷰도 아주 멋집니다 ^.^']

# %% [markdown]
# ## 다음 페이지

# %%
url ='https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-Lotte_City_Hotel_Daejeon-Daejeon.html'
     
'''    'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-or5-Lotte_City_Hotel_Daejeon-Daejeon.html#REVIEWS',
      'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-or10-Lotte_City_Hotel_Daejeon-Daejeon.html#REVIEWS',
      'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-or15-Lotte_City_Hotel_Daejeon-Daejeon.html#REVIEWS',
      'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-or20-Lotte_City_Hotel_Daejeon-Daejeon.html#REVIEWS',
      'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-or25-Lotte_City_Hotel_Daejeon-Daejeon.html#REVIEWS'
     ]'''
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import time


browser = Chrome()
browser.get(url)
flag = True
n=0
while flag:
    print(flag)
    try:# 무조건 link에 copyselector를 추가 후에 find_elements를 해야 한다.
        link = "#component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.next.primary"
        next_page = browser.find_elements(By.CSS_SELECTOR,link)   
          
        if not next_page:
            flag = False


        next_page[0].click()

        
    except:
        print('예외처리 발생', n)
        if  not next_page:
            flag = False

    n+=1
    print(n)
# !-1 #component_15 > div > div:nth-child(3) > div.MD > div > a
# 2-1 #component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.previous.secondary
# 2-2 #component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.next.primary
# 3-1 #component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.previous.secondary
# 3-2 #component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.next.primary
# Out:
# True
# 1
# True
# 2
# True
# 3
# True
# 4
# True
# 5
# True
# 6
# True
# 7
# True
# 8
# True
# 9
# True
# 10
# True
# 11
# True
# 12
# True
# 13
# True
# 14
# True
# 15
# True
# 16
# True
# 17
# True
# 18
# True
# 19
# True
# 20
# True
# 21
# True
# 22
# True
# 23
# True
# 24
# True
# 25
# True
# 26
# True
# 27
# True
# 28
# True
# 29
# True
# 30
# True
# 31
# True
# 32
# True
# 33
# True
# 34
# True
# 35
# True
# 36
# True
# 37
# True
# 38
# True
# 39
# True
# 40
# True
# 41
# True
# 42
# True
# 43
# True
# 44
# True
# 45
# True
# 46
# True
# 47
# True
# 48
# True
# 49
# True
# 50
# True
# 51
# True
# 52
# True
# 53
# True
# 54
# True
# 55
# True
# 예외처리 발생 55
# 56

# %%
url = 'https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-Lotte_City_Hotel_Daejeon-Daejeon.html'
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import time
browser = Chrome()
browser.get(url)
re_list = []
flag = True
n=0
while flag:
    print(flag)
    try:
        # 리뷰 가져오기
        class_reviews = browser.find_elements(By.CSS_SELECTOR,'.QewHA.H4._a > span')
        for span_review in class_reviews:
            re_list.append(span_review.text)
        
        # 다음 페이지 넘어가기
        # 무조건 link에 copyselector를 추가 후에 find_elements를 해야 한다.
        link = "#component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.next.primary"
        next_page = browser.find_elements(By.CSS_SELECTOR,link)   
          
        if not next_page:
            flag = False


        next_page[0].click()

        
    except:
        print('예외처리 발생', n)
        if  not next_page:
            flag = False

    n+=1
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# 예외처리 발생 55

# %%
re_list
# Out:
# ['헐리우드 부터 다양한 룸타입과 계절별 PKG등 여러 프로모션이 있는것 좋지만 최근 구로에 숙박한후 대전 을 기록한다 헐리우드 킹인데 더블을 두개 붙여놓았었던 적도 있고, 가급적 조용함을 원했는데 층별실외기가 있는방으로 배치받아 교체를 했던적도 있고 구로, 김포, 대전, 마포 등 여러 롯데시티중에서 주차장 이용은 나름 부족한 부분이 없으나 배려가 너무 부족한것 같다 4월 5월 이용시 한번의 조식 이용도 예전에 비해 퀄리티가 많이 떨어졌다 작년 코로나땐 엄청 세심했는데 지금은 너무 아쉬운곳',
#  '뷰가 특별한건없고 그냥 편하게 자기 좋은곳!! 이건 체크아웃 하고나서 알게된 사실인데 미리 가습기 얘기하면 무료대여(?) 할수있다!! 친구가 자는데 건조하다해서 검색해보니 그런서비스도🤭',
#  '갑천과 유등천의 흐름을 한눈에 볼수 있는 대전에선 최고의 리버뷰를 자랑합니다. 침실과 다용도실이 나눠져있어서 공간 분리도 훌륭하고, 역시나 청소상태 침구류 상태 최상입니다 잘쉬었다가 갑니다!',
#  '시설이 깔끔하고 조용합니다. 근처에 식당과 술집이 많지는 않습니다. 편의점은 옆건물에 있습니다. 대전 시내 중심가까지 택시를 이용했습니다.',
#  '고향에 갈때마다 언제나 투숙하는 곳입니다. 신축 호텔이라 그런지 깔끔한 인상을 주는 곳입니다. 객실 컨디션도 만족합니다. 갑천을 바라보는 뷰도 아주 멋집니다 ^.^',
#  '헐리우드 부터 다양한 룸타입과 계절별 PKG등 여러 프로모션이 있는것 좋지만 최근 구로에 숙박한후 대전 을 기록한다 헐리우드 킹인데 더블을 두개 붙여놓았었던 적도 있고, 가급적 조용함을 원했는데 층별실외기가 있는방으로 배치받아 교체를 했던적도 있고 구로, 김포, 대전, 마포 등 여러 롯데시티중에서 주차장 이용은 나름 부족한 부분이 없으나 배려가 너무 부족한것 같다 4월 5월 이용시 한번의 조식 이용도 예전에 비해 퀄리티가 많이 떨어졌다 작년 코로나땐 엄청 세심했는데 지금은 너무 아쉬운곳',
# ...

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By

# 다음 페이지 넘어가기
def def_next_page(browser):
    browser = browser
    # 무조건 link에 copyselector를 추가 후에 find_elements를 해야 한다.
    link = "#component_15 > div > div:nth-child(3) > div.MD > div > a.ui_button.nav.next.primary"
    next_page = browser.find_elements(By.CSS_SELECTOR,link)   

    return next_page

   # 리뷰 가져오기     
def def_crawling_review(browser):
    browser = browser
    class_reviews = []
    re_list = []
    class_reviews = browser.find_elements(By.CSS_SELECTOR,'.QewHA.H4._a > span')
    for span_review in class_reviews:
        re_list.append(span_review.text)
    return re_list
    
def def_hotel_reivews_crawling(url):
    url = url
    browser = Chrome()
    browser.get(url)

    flag = True
    n=0
    total_review = []
    next_page = None
    
    while flag:
        try:
            # 가져오 데이터를 임시변수에 저장
            return_def_crawling_review = def_crawling_review(browser)

            #가져온 데이터를 전체 데이터 리스트에 적재
            total_review.extend(return_def_crawling_review)
            #다음 페이지 이동 및 다음 페이지 여부 판별 True or False 저장
            next_page = def_next_page(browser)
            
            #  다음 페이지가 있다면 이동
            next_page[0].click()
            
        # 마지막 페이지 여부 판별 없다면 종료
        except:
            print('예외처리 발생', n)
            # 가장 오류가 많이 나는 구간이 첫번째 반복
            if  n and not next_page :
                flag = False
        n+=1
    return total_review

# %% [markdown]
# # 데이터 수집

# %%
total_review = def_hotel_reivews_crawling('https://www.tripadvisor.co.kr/Hotel_Review-g297887-d6378639-Reviews-Lotte_City_Hotel_Daejeon-Daejeon.html')
# Out:
# 예외처리 발생 10
# 예외처리 발생 55

# %%
total_review
# Out:
# ['헐리우드 부터 다양한 룸타입과 계절별 PKG등 여러 프로모션이 있는것 좋지만 최근 구로에 숙박한후 대전 을 기록한다 헐리우드 킹인데 더블을 두개 붙여놓았었던 적도 있고, 가급적 조용함을 원했는데 층별실외기가 있는방으로 배치받아 교체를 했던적도 있고 구로, 김포, 대전, 마포 등 여러 롯데시티중에서 주차장 이용은 나름 부족한 부분이 없으나 배려가 너무 부족한것 같다 4월 5월 이용시 한번의 조식 이용도 예전에 비해 퀄리티가 많이 떨어졌다 작년 코로나땐 엄청 세심했는데 지금은 너무 아쉬운곳',
#  '뷰가 특별한건없고 그냥 편하게 자기 좋은곳!! 이건 체크아웃 하고나서 알게된 사실인데 미리 가습기 얘기하면 무료대여(?) 할수있다!! 친구가 자는데 건조하다해서 검색해보니 그런서비스도🤭',
#  '갑천과 유등천의 흐름을 한눈에 볼수 있는 대전에선 최고의 리버뷰를 자랑합니다. 침실과 다용도실이 나눠져있어서 공간 분리도 훌륭하고, 역시나 청소상태 침구류 상태 최상입니다 잘쉬었다가 갑니다!',
#  '시설이 깔끔하고 조용합니다. 근처에 식당과 술집이 많지는 않습니다. 편의점은 옆건물에 있습니다. 대전 시내 중심가까지 택시를 이용했습니다.',
#  '고향에 갈때마다 언제나 투숙하는 곳입니다. 신축 호텔이라 그런지 깔끔한 인상을 주는 곳입니다. 객실 컨디션도 만족합니다. 갑천을 바라보는 뷰도 아주 멋집니다 ^.^',
#  '헐리우드 부터 다양한 룸타입과 계절별 PKG등 여러 프로모션이 있는것 좋지만 최근 구로에 숙박한후 대전 을 기록한다 헐리우드 킹인데 더블을 두개 붙여놓았었던 적도 있고, 가급적 조용함을 원했는데 층별실외기가 있는방으로 배치받아 교체를 했던적도 있고 구로, 김포, 대전, 마포 등 여러 롯데시티중에서 주차장 이용은 나름 부족한 부분이 없으나 배려가 너무 부족한것 같다 4월 5월 이용시 한번의 조식 이용도 예전에 비해 퀄리티가 많이 떨어졌다 작년 코로나땐 엄청 세심했는데 지금은 너무 아쉬운곳',
# ...
